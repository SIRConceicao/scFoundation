# %% [markdown]
# https://github.com/biomap-research/scFoundation/issues/33
#
# A100 40G or 80G for local inference.

# %%
A100 40G or 80G for local inference.

# %% [markdown]
# Cell Embeddings

# %%
# !python get_embedding.py \
  --task_name Baron \
  --input_type singlecell \
  --output_type cell \
  --pool_type all \
  --tgthighres a5 \
  --data_path ./examples/enhancement/Baron_enhancement.csv \
  --save_path ./examples/enhancement/ \
  --pre_normalized F \
  --version rde
# Out:
# Traceback (most recent call last):
#   File "/foundational_models/scFoundation/model/get_embedding.py", line 13, in <module>
#     from load import *
#   File "/foundational_models/scFoundation/model/load.py", line 8, in <module>
#     from pretrainmodels import select_model
#   File "/foundational_models/scFoundation/model/pretrainmodels/__init__.py", line 3, in <module>
#     from pretrainmodels.select_model import select_model
#   File "/foundational_models/scFoundation/model/pretrainmodels/select_model.py", line 5, in <module>
#     from .performer import PerformerModule
#   File "/foundational_models/scFoundation/model/pretrainmodels/performer.py", line 13, in <module>
#     from local_attention import LocalAttention
#   File "/root/miniconda3/envs/scfoundation/lib/python3.10/site-packages/local_attention/__init__.py", line 2, in <module>
#     from local_attention.transformer import LocalTransformer, LocalMHA, DynamicPositionBias
# ...
