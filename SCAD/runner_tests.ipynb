# %% [markdown]
# # SCAD

# %%
# !pwd
# Out:
# /foundational_models/scFoundation/SCAD

# %% [markdown]
# %%bash
# cd /data/split_norm/
# # Without embedding
# python split_data_SCAD_5fold_norm.py --drug Sorafenib --emb 0
# # With embedding
# python split_data_SCAD_5fold_norm.py --drug Sorafenib --emb 1
